# %%
import pandas as pd

# %%
df =pd.read_csv("crop_production.csv")
df.head(6)
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop     Area  Production
# 0             Arecanut   1254.0      2000.0
# 1  Other Kharif pulses      2.0         1.0
# 2                 Rice    102.0       321.0
# 3               Banana    176.0       641.0
# 4            Cashewnut    720.0       165.0
# 5             Coconut   18168.0  65100000.0

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
df.dropna()
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
df.dropna()
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [242361 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.dropna()
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [246091 rows x 7 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.dropna()
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [246091 rows x 7 columns]

# %%
df.dropna()
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [246091 rows x 7 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.dropna()
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production      Yield
# 0                  Arecanut    1254.0      2000.0   1.594896
# 1       Other Kharif pulses       2.0         1.0   0.500000
# 2                      Rice     102.0       321.0   3.147059
# 3                    Banana     176.0       641.0   3.642045
# 4                 Cashewnut     720.0       165.0   0.229167
# ...                     ...       ...         ...        ...
# 246086                 Rice     306.0       801.0   2.617647
# 246087              Sesamum     627.0       463.0   0.738437
# 246088            Sugarcane     324.0     16250.0  50.154321
# 246089                 Rice  279151.0    597899.0   2.141848
# 246090              Sesamum     175.0        88.0   0.502857
#
# [242361 rows x 8 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df['Yield'] = (df['Production'] / df['Area'])
df.head(10)
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 5  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 6  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 7  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 8  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 9  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop     Area  Production        Yield
# 0             Arecanut   1254.0      2000.0     1.594896
# 1  Other Kharif pulses      2.0         1.0     0.500000
# 2                 Rice    102.0       321.0     3.147059
# 3               Banana    176.0       641.0     3.642045
# 4            Cashewnut    720.0       165.0     0.229167
# 5             Coconut   18168.0  65100000.0  3583.223250
# 6           Dry ginger     36.0       100.0     2.777778
# 7            Sugarcane      1.0         2.0     2.000000
# 8         Sweet potato      5.0        15.0     3.000000
# 9              Tapioca     40.0       169.0     4.225000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
#  7   Yield          242361 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 15.0+ MB

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production     Yield
# 0             Arecanut  1254.0      2000.0  1.594896
# 1  Other Kharif pulses     2.0         1.0  0.500000
# 2                 Rice   102.0       321.0  3.147059
# 3               Banana   176.0       641.0  3.642045
# 4            Cashewnut   720.0       165.0  0.229167

# %%
df.tail()
# Out:
#          State_Name District_Name  Crop_Year       Season       Crop  \
# 246086  West Bengal       PURULIA       2014  Summer            Rice
# 246087  West Bengal       PURULIA       2014  Summer         Sesamum
# 246088  West Bengal       PURULIA       2014  Whole Year   Sugarcane
# 246089  West Bengal       PURULIA       2014  Winter            Rice
# 246090  West Bengal       PURULIA       2014  Winter         Sesamum
#
#             Area  Production      Yield
# 246086     306.0       801.0   2.617647
# 246087     627.0       463.0   0.738437
# 246088     324.0     16250.0  50.154321
# 246089  279151.0    597899.0   2.141848
# 246090     175.0        88.0   0.502857

# %%
df['Yield'].value_counts()
# Out:
# Yield
# 1.000000    7096
# 0.500000    4051
# 0.000000    3523
# 0.333333    1887
# 2.000000    1675
#             ...
# 0.213713       1
# 1.384709       1
# 1.650717       1
# 1.026958       1
# 2.141848       1
# Name: count, Length: 144943, dtype: int64

# %%
x=df.drop("Yield", axis=1)
y=df['Yield']

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 246091 entries, 0 to 246090
# Series name: Yield
# Non-Null Count   Dtype
# --------------   -----
# 242361 non-null  float64
# dtypes: float64(1)
# memory usage: 1.9 MB

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state = 1, test_size=0.2)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 196872 entries, 25613 to 128037
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     196872 non-null  object
#  1   District_Name  196872 non-null  object
#  2   Crop_Year      196872 non-null  int64
#  3   Season         196872 non-null  object
#  4   Crop           196872 non-null  object
#  5   Area           196872 non-null  float64
#  6   Production     193869 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 12.0+ MB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49219 entries, 233380 to 205199
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State_Name     49219 non-null  object
#  1   District_Name  49219 non-null  object
#  2   Crop_Year      49219 non-null  int64
#  3   Season         49219 non-null  object
#  4   Crop           49219 non-null  object
#  5   Area           49219 non-null  float64
#  6   Production     48492 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 3.0+ MB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 196872 entries, 25613 to 128037
# Series name: Yield
# Non-Null Count   Dtype
# --------------   -----
# 193869 non-null  float64
# dtypes: float64(1)
# memory usage: 3.0 MB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 49219 entries, 233380 to 205199
# Series name: Yield
# Non-Null Count  Dtype
# --------------  -----
# 48492 non-null  float64
# dtypes: float64(1)
# memory usage: 769.0 KB

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(x_train,y_train)
model.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 4
#       1 from sklearn.ensemble import RandomForestRegressor
#       3 model = RandomForestRegressor()
# ----> 4 model.fit(x_train,y_train)
#       5 model.score(x_test, y_test)
#
# File ~\users\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\users\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\users\Lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:883, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     881 if sp.issparse(array):
#     882     _ensure_no_complex_data(array)
# --> 883     array = _ensure_sparse_format(
#     884         array,
#     885         accept_sparse=accept_sparse,
#     886         dtype=dtype,
#     887         copy=copy,
#     888         force_all_finite=force_all_finite,
#     889         accept_large_sparse=accept_large_sparse,
#     890         estimator_name=estimator_name,
#     891         input_name=input_name,
#     892     )
#     893 else:
#     894     # If np.array(..) gives ComplexWarning, then we convert the warning
#     895     # to an error. This is needed because specifying a non complex
#     896     # dtype to the function converts complex to real dtype,
#     897     # thereby passing the test made in the lines following the scope
#     898     # of warnings context manager.
#     899     with warnings.catch_warnings():
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:573, in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse, estimator_name, input_name)
#     568         warnings.warn(
#     569             "Can't check %s sparse matrix for nan or inf." % spmatrix.format,
#     570             stacklevel=2,
#     571         )
#     572     else:
# --> 573         _assert_all_finite(
#     574             spmatrix.data,
#     575             allow_nan=force_all_finite == "allow-nan",
#     576             estimator_name=estimator_name,
#     577             input_name=input_name,
#     578         )
#     580 return spmatrix
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# RandomForestRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
categorical_features = ["State_Name", "District_Name", "Season", "Crop"]
one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot", one_hot, categorical_features)],remainder="passthrough")
transformed_x= transformer.fit_transform(x)
transformed_x
# Out:
# <246091x812 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1719114 stored elements in Compressed Sparse Row format>

# %%
import pandas as pd
pd.DataFrame(transformed_x)
# Out:
#                                                         0
# 0         (0, 0)\t1.0\n  (0, 460)\t1.0\n  (0, 680)\t1....
# 1         (0, 0)\t1.0\n  (0, 460)\t1.0\n  (0, 680)\t1....
# 2         (0, 0)\t1.0\n  (0, 460)\t1.0\n  (0, 680)\t1....
# 3         (0, 0)\t1.0\n  (0, 460)\t1.0\n  (0, 683)\t1....
# 4         (0, 0)\t1.0\n  (0, 460)\t1.0\n  (0, 683)\t1....
# ...                                                   ...
# 246086    (0, 32)\t1.0\n  (0, 504)\t1.0\n  (0, 682)\t1...
# 246087    (0, 32)\t1.0\n  (0, 504)\t1.0\n  (0, 682)\t1...
# 246088    (0, 32)\t1.0\n  (0, 504)\t1.0\n  (0, 683)\t1...
# 246089    (0, 32)\t1.0\n  (0, 504)\t1.0\n  (0, 684)\t1...
# 246090    (0, 32)\t1.0\n  (0, 504)\t1.0\n  (0, 684)\t1...
#
# [246091 rows x 1 columns]

# %%
dummies = pd.get_dummies(df[["State_Name", "District_Name", "Season", "Crop"]])
dummies
# Out:
#         State_Name_Andaman and Nicobar Islands  State_Name_Andhra Pradesh  \
# 0                                         True                      False
# 1                                         True                      False
# 2                                         True                      False
# 3                                         True                      False
# 4                                         True                      False
# ...                                        ...                        ...
# 246086                                   False                      False
# 246087                                   False                      False
# 246088                                   False                      False
# 246089                                   False                      False
# 246090                                   False                      False
#
#         State_Name_Arunachal Pradesh  State_Name_Assam  State_Name_Bihar  \
# 0                              False             False             False
# 1                              False             False             False
# 2                              False             False             False
# 3                              False             False             False
# 4                              False             False             False
# ...                              ...               ...               ...
# 246086                         False             False             False
# 246087                         False             False             False
# 246088                         False             False             False
# 246089                         False             False             False
# 246090                         False             False             False
#
#         State_Name_Chandigarh  State_Name_Chhattisgarh  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ...                       ...                      ...
# 246086                  False                    False
# 246087                  False                    False
# 246088                  False                    False
# 246089                  False                    False
# 246090                  False                    False
#
#         State_Name_Dadra and Nagar Haveli  State_Name_Goa  State_Name_Gujarat  \
# 0                                   False           False               False
# 1                                   False           False               False
# 2                                   False           False               False
# 3                                   False           False               False
# 4                                   False           False               False
# ...                                   ...             ...                 ...
# 246086                              False           False               False
# 246087                              False           False               False
# 246088                              False           False               False
# 246089                              False           False               False
# 246090                              False           False               False
#
#         ...  Crop_Turmeric  Crop_Turnip  Crop_Urad  Crop_Varagu  \
# 0       ...          False        False      False        False
# 1       ...          False        False      False        False
# 2       ...          False        False      False        False
# 3       ...          False        False      False        False
# 4       ...          False        False      False        False
# ...     ...            ...          ...        ...          ...
# 246086  ...          False        False      False        False
# 246087  ...          False        False      False        False
# 246088  ...          False        False      False        False
# 246089  ...          False        False      False        False
# 246090  ...          False        False      False        False
#
#         Crop_Water Melon  Crop_Wheat  Crop_Yam  Crop_other fibres  \
# 0                  False       False     False              False
# 1                  False       False     False              False
# 2                  False       False     False              False
# 3                  False       False     False              False
# 4                  False       False     False              False
# ...                  ...         ...       ...                ...
# 246086             False       False     False              False
# 246087             False       False     False              False
# 246088             False       False     False              False
# 246089             False       False     False              False
# 246090             False       False     False              False
#
#         Crop_other misc. pulses  Crop_other oilseeds
# 0                         False                False
# 1                         False                False
# 2                         False                False
# 3                         False                False
# 4                         False                False
# ...                         ...                  ...
# 246086                    False                False
# 246087                    False                False
# 246088                    False                False
# 246089                    False                False
# 246090                    False                False
#
# [246091 rows x 809 columns]

# %%
import numpy as np
np.random.seed(42)
x_train, x_test , y_train ,y_test = train_test_split(transformed_x, y, test_size=0.2)
model.fit(x_train , y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 4
#       2 np.random.seed(42)
#       3 x_train, x_test , y_train ,y_test = train_test_split(transformed_x, y, test_size=0.2)
# ----> 4 model.fit(x_train , y_train)
#
# File ~\users\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\users\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\users\Lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:883, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     881 if sp.issparse(array):
#     882     _ensure_no_complex_data(array)
# --> 883     array = _ensure_sparse_format(
#     884         array,
#     885         accept_sparse=accept_sparse,
#     886         dtype=dtype,
#     887         copy=copy,
#     888         force_all_finite=force_all_finite,
#     889         accept_large_sparse=accept_large_sparse,
#     890         estimator_name=estimator_name,
#     891         input_name=input_name,
#     892     )
#     893 else:
#     894     # If np.array(..) gives ComplexWarning, then we convert the warning
#     895     # to an error. This is needed because specifying a non complex
#     896     # dtype to the function converts complex to real dtype,
#     897     # thereby passing the test made in the lines following the scope
#     898     # of warnings context manager.
#     899     with warnings.catch_warnings():
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:573, in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse, estimator_name, input_name)
#     568         warnings.warn(
#     569             "Can't check %s sparse matrix for nan or inf." % spmatrix.format,
#     570             stacklevel=2,
#     571         )
#     572     else:
# --> 573         _assert_all_finite(
#     574             spmatrix.data,
#     575             allow_nan=force_all_finite == "allow-nan",
#     576             estimator_name=estimator_name,
#     577             input_name=input_name,
#     578         )
#     580 return spmatrix
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# RandomForestRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
df.dropna()
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production      Yield
# 0                  Arecanut    1254.0      2000.0   1.594896
# 1       Other Kharif pulses       2.0         1.0   0.500000
# 2                      Rice     102.0       321.0   3.147059
# 3                    Banana     176.0       641.0   3.642045
# 4                 Cashewnut     720.0       165.0   0.229167
# ...                     ...       ...         ...        ...
# 246086                 Rice     306.0       801.0   2.617647
# 246087              Sesamum     627.0       463.0   0.738437
# 246088            Sugarcane     324.0     16250.0  50.154321
# 246089                 Rice  279151.0    597899.0   2.141848
# 246090              Sesamum     175.0        88.0   0.502857
#
# [242361 rows x 8 columns]

# %%
df.isnull()
# Out:
#         State_Name  District_Name  Crop_Year  Season   Crop   Area  \
# 0            False          False      False   False  False  False
# 1            False          False      False   False  False  False
# 2            False          False      False   False  False  False
# 3            False          False      False   False  False  False
# 4            False          False      False   False  False  False
# ...            ...            ...        ...     ...    ...    ...
# 246086       False          False      False   False  False  False
# 246087       False          False      False   False  False  False
# 246088       False          False      False   False  False  False
# 246089       False          False      False   False  False  False
# 246090       False          False      False   False  False  False
#
#         Production  Yield
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...            ...    ...
# 246086       False  False
# 246087       False  False
# 246088       False  False
# 246089       False  False
# 246090       False  False
#
# [246091 rows x 8 columns]

# %%
df.dropna()
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production      Yield
# 0                  Arecanut    1254.0      2000.0   1.594896
# 1       Other Kharif pulses       2.0         1.0   0.500000
# 2                      Rice     102.0       321.0   3.147059
# 3                    Banana     176.0       641.0   3.642045
# 4                 Cashewnut     720.0       165.0   0.229167
# ...                     ...       ...         ...        ...
# 246086                 Rice     306.0       801.0   2.617647
# 246087              Sesamum     627.0       463.0   0.738437
# 246088            Sugarcane     324.0     16250.0  50.154321
# 246089                 Rice  279151.0    597899.0   2.141848
# 246090              Sesamum     175.0        88.0   0.502857
#
# [242361 rows x 8 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
import numpy as np
np.random.seed(42)
x_train, x_test , y_train ,y_test = train_test_split(transformed_x, y, test_size=0.2)
model.fit(x_train , y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 4
#       2 np.random.seed(42)
#       3 x_train, x_test , y_train ,y_test = train_test_split(transformed_x, y, test_size=0.2)
# ----> 4 model.fit(x_train , y_train)
#
# File ~\users\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\users\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\users\Lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:883, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     881 if sp.issparse(array):
#     882     _ensure_no_complex_data(array)
# --> 883     array = _ensure_sparse_format(
#     884         array,
#     885         accept_sparse=accept_sparse,
#     886         dtype=dtype,
#     887         copy=copy,
#     888         force_all_finite=force_all_finite,
#     889         accept_large_sparse=accept_large_sparse,
#     890         estimator_name=estimator_name,
#     891         input_name=input_name,
#     892     )
#     893 else:
#     894     # If np.array(..) gives ComplexWarning, then we convert the warning
#     895     # to an error. This is needed because specifying a non complex
#     896     # dtype to the function converts complex to real dtype,
#     897     # thereby passing the test made in the lines following the scope
#     898     # of warnings context manager.
#     899     with warnings.catch_warnings():
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:573, in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse, estimator_name, input_name)
#     568         warnings.warn(
#     569             "Can't check %s sparse matrix for nan or inf." % spmatrix.format,
#     570             stacklevel=2,
#     571         )
#     572     else:
# --> 573         _assert_all_finite(
#     574             spmatrix.data,
#     575             allow_nan=force_all_finite == "allow-nan",
#     576             estimator_name=estimator_name,
#     577             input_name=input_name,
#     578         )
#     580 return spmatrix
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# RandomForestRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
df= df.dropna()
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production      Yield
# 0                  Arecanut    1254.0      2000.0   1.594896
# 1       Other Kharif pulses       2.0         1.0   0.500000
# 2                      Rice     102.0       321.0   3.147059
# 3                    Banana     176.0       641.0   3.642045
# 4                 Cashewnut     720.0       165.0   0.229167
# ...                     ...       ...         ...        ...
# 246086                 Rice     306.0       801.0   2.617647
# 246087              Sesamum     627.0       463.0   0.738437
# 246088            Sugarcane     324.0     16250.0  50.154321
# 246089                 Rice  279151.0    597899.0   2.141848
# 246090              Sesamum     175.0        88.0   0.502857
#
# [242361 rows x 8 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
import numpy as np
np.random.seed(42)
x_train, x_test , y_train ,y_test = train_test_split(transformed_x, y, test_size=0.2)
model.fit(x_train , y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 4
#       2 np.random.seed(42)
#       3 x_train, x_test , y_train ,y_test = train_test_split(transformed_x, y, test_size=0.2)
# ----> 4 model.fit(x_train , y_train)
#
# File ~\users\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\users\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\users\Lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:883, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     881 if sp.issparse(array):
#     882     _ensure_no_complex_data(array)
# --> 883     array = _ensure_sparse_format(
#     884         array,
#     885         accept_sparse=accept_sparse,
#     886         dtype=dtype,
#     887         copy=copy,
#     888         force_all_finite=force_all_finite,
#     889         accept_large_sparse=accept_large_sparse,
#     890         estimator_name=estimator_name,
#     891         input_name=input_name,
#     892     )
#     893 else:
#     894     # If np.array(..) gives ComplexWarning, then we convert the warning
#     895     # to an error. This is needed because specifying a non complex
#     896     # dtype to the function converts complex to real dtype,
#     897     # thereby passing the test made in the lines following the scope
#     898     # of warnings context manager.
#     899     with warnings.catch_warnings():
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:573, in _ensure_sparse_format(spmatrix, accept_sparse, dtype, copy, force_all_finite, accept_large_sparse, estimator_name, input_name)
#     568         warnings.warn(
#     569             "Can't check %s sparse matrix for nan or inf." % spmatrix.format,
#     570             stacklevel=2,
#     571         )
#     572     else:
# --> 573         _assert_all_finite(
#     574             spmatrix.data,
#     575             allow_nan=force_all_finite == "allow-nan",
#     576             estimator_name=estimator_name,
#     577             input_name=input_name,
#     578         )
#     580 return spmatrix
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~\users\Lib\site-packages\sklearn\utils\validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# RandomForestRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
